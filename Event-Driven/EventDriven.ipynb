# %%
import string
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import nltk
from nltk.corpus import  stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from difflib import SequenceMatcher
import warnings
warnings.filterwarnings('ignore')

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('words')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\WB\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\WB\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\WB\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# # from google.colab import drive
# # drive.mount('/content/drive')

# # Import the necessary modules
# # !pip install language_tool_python
# import language_tool_python


# tool = language_tool_python.LanguageTool('en-US')

# sentence = "The system shall  specific player id team."

# matches = tool.check(sentence)

# corrected_sentence = language_tool_python.utils.correct(sentence, matches)

# # Print the corrected sentence
# print(corrected_sentence)

# %% [markdown]
# **preprocessing**

# %%
data = pd.read_csv('./Event.csv', encoding='unicode-escape')
data
# Out:
#                                        Raw Requirements        Type  \
# 0     The Game must be developed using the Unity Gam...  ubiquitous
# 1     The Game must be programmed using the C# langu...  ubiquitous
# 2     The Game must feature accurate sound effects a...  ubiquitous
# 3     The Game must be playable using the keyboard k...  ubiquitous
# 4     The Game must offer a compelling story which w...  ubiquitous
# ...                                                 ...         ...
# 3522                                                NaN         NaN
# 3523                                                NaN         NaN
# 3524                                                NaN         NaN
# 3525                                                NaN         NaN
# 3526                                                NaN         NaN
#
#             type                   Requirement with Standard Syntax Domain  \
# 0     ubiquitous  The game shall be developed using unity game e...   Game
# 1     ubiquitous  The game shall be written in C# and use Unity ...   Game
# 2     ubiquitous  The Game shall feature accurate sound effects ...   Game
# 3     ubiquitous  The game shall be playable using mouse and key...   Game
# 4     ubiquitous  The Game shall offer a compelling story which ...   Game
# ...          ...                                                ...    ...
# 3522         NaN                                                NaN    NaN
# 3523         NaN                                                NaN    NaN
# 3524         NaN                                                NaN    NaN
# 3525         NaN                                                NaN    NaN
# 3526         NaN                                                NaN    NaN
#
#       sub_domain
# 0     Mobile app
# 1     Mobile app
# 2     Mobile app
# 3     Mobile app
# 4     Mobile app
# ...          ...
# 3522         NaN
# 3523         NaN
# 3524         NaN
# 3525         NaN
# 3526         NaN
#
# [3527 rows x 6 columns]

# %%
data.columns
# printing all the columns headers
# Out:
# Index(['Raw Requirements', ' Type', ' type',
#        'Requirement with Standard Syntax', 'Domain', 'sub_domain'],
#       dtype='object')

# %%
data = data[['Raw Requirements', 'Requirement with Standard Syntax', ' type', 'Domain', 'sub_domain']]
# selecting only the required columns

# %%
data
# printing the data
# Out:
#                                        Raw Requirements  \
# 0     The Game must be developed using the Unity Gam...
# 1     The Game must be programmed using the C# langu...
# 2     The Game must feature accurate sound effects a...
# 3     The Game must be playable using the keyboard k...
# 4     The Game must offer a compelling story which w...
# ...                                                 ...
# 3522                                                NaN
# 3523                                                NaN
# 3524                                                NaN
# 3525                                                NaN
# 3526                                                NaN
#
#                        Requirement with Standard Syntax        type Domain  \
# 0     The game shall be developed using unity game e...  ubiquitous   Game
# 1     The game shall be written in C# and use Unity ...  ubiquitous   Game
# 2     The Game shall feature accurate sound effects ...  ubiquitous   Game
# 3     The game shall be playable using mouse and key...  ubiquitous   Game
# 4     The Game shall offer a compelling story which ...  ubiquitous   Game
# ...                                                 ...         ...    ...
# 3522                                                NaN         NaN    NaN
# 3523                                                NaN         NaN    NaN
# 3524                                                NaN         NaN    NaN
# 3525                                                NaN         NaN    NaN
# 3526                                                NaN         NaN    NaN
#
#       sub_domain
# 0     Mobile app
# 1     Mobile app
# 2     Mobile app
# 3     Mobile app
# 4     Mobile app
# ...          ...
# 3522         NaN
# 3523         NaN
# 3524         NaN
# 3525         NaN
# 3526         NaN
#
# [3527 rows x 5 columns]

# %%
data.dropna(inplace=True)
# dropping the rows with null values in any column
data
# Out:
#                                      Raw Requirements  \
# 0   The Game must be developed using the Unity Gam...
# 1   The Game must be programmed using the C# langu...
# 2   The Game must feature accurate sound effects a...
# 3   The Game must be playable using the keyboard k...
# 4   The Game must offer a compelling story which w...
# 5   The Game must implement AI for the enemies and...
# 6   The Game must challenge the user to think and ...
# 7   The user shall be able to register with in the...
# 8            Login should be available in the website
# 9   Request Cricket Tournament should be available...
# 10  Name of Tournament should be available to the ...
# 11  Starting and ending date of tournament should ...
# 12  Each team players will have Names, Contacts nu...
# 13   The website shall assign the user a specific ID.
# 14  Each player will have their own FirstName Last...
# 15  Each Players will have their own specific play...
# 16  The website shall enable to store the Roles (B...
# 17  The website will also store the Date of the to...
# 18  Every Match Detail will have a specific Match ...
# 19  Every Match will have a specific scorecard whi...
# 20  The Match Scorecard will contain the total run...
#
#                      Requirement with Standard Syntax        type Domain  \
# 0   The game shall be developed using unity game e...  ubiquitous   Game
# 1   The game shall be written in C# and use Unity ...  ubiquitous   Game
# 2   The Game shall feature accurate sound effects ...  ubiquitous   Game
# 3   The game shall be playable using mouse and key...  ubiquitous   Game
# 4   The Game shall offer a compelling story which ...  ubiquitous   Game
# 5   The Game shall implement AI for the enemies an...  ubiquitous   Game
# 6   The Game shall challenge the user to think and...  ubiquitous   Game
# 7         The system shall allow the user to register  ubiquitous   Game
# 8            The system shall provide a login option.  ubiquitous   Game
# 9   the System shall provide the Request Cricket T...  ubiquitous   Game
# 10   The system shall provide the Name of Tournament.  ubiquitous   Game
# 11  The system shall provide starting and ending d...  ubiquitous   Game
# 12  the  team players shall have Names, Contacts n...  ubiquitous   Game
# 13    The system shall assign the user a specific ID.  ubiquitous   Game
# 14  The system shall allow the player to enter the...  ubiquitous   Game
# 15  The system shall provide the specific player i...  ubiquitous   Game
# 16  The system shall store the Roles (Batsmen/bowl...  ubiquitous   Game
# 17  The system shall store the Date of the tournam...  ubiquitous   Game
# 18  The system shall provide a specific ID to ever...  ubiquitous   Game
# 19  The system shall be able to  have a specific s...  ubiquitous   Game
# 20  The system shall have the match scorecard whic...  ubiquitous   Game
#
#     sub_domain
# 0   Mobile app
# 1   Mobile app
# 2   Mobile app
# 3   Mobile app
# 4   Mobile app
# 5   Mobile app
# 6   Mobile app
# 7   Mobile app
# 8   Mobile app
# 9   Mobile app
# 10  Mobile app
# 11  Mobile app
# 12  Mobile app
# 13  Mobile app
# 14  Mobile app
# 15  Mobile app
# 16  Mobile app
# 17  Mobile app
# 18  Mobile app
# 19  Mobile app
# 20  Mobile app

# %%
data.info()
# printing the information about the data frame like the number of rows and columns, the number of non-null values in each column and the data type of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21 entries, 0 to 20
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Raw Requirements                  21 non-null     object
#  1   Requirement with Standard Syntax  21 non-null     object
#  2    type                             21 non-null     object
#  3   Domain                            21 non-null     object
#  4   sub_domain                        21 non-null     object
# dtypes: object(5)
# memory usage: 1008.0+ bytes

# %%
data.isnull().sum()
# printing the number of null values in each column
# Out:
# Raw Requirements                    0
# Requirement with Standard Syntax    0
#  type                               0
# Domain                              0
# sub_domain                          0
# dtype: int64

# %%
data['raw_length'] = data['Raw Requirements'].str.len()
# creating a new column raw_length which contains the length of the raw requirements
data['standard_length'] = data['Requirement with Standard Syntax'].str.len()
# creating a new column standard_length which contains the length of the Requirement with Standard Syntax
data
# Out:
#                                      Raw Requirements  \
# 0   The Game must be developed using the Unity Gam...
# 1   The Game must be programmed using the C# langu...
# 2   The Game must feature accurate sound effects a...
# 3   The Game must be playable using the keyboard k...
# 4   The Game must offer a compelling story which w...
# 5   The Game must implement AI for the enemies and...
# 6   The Game must challenge the user to think and ...
# 7   The user shall be able to register with in the...
# 8            Login should be available in the website
# 9   Request Cricket Tournament should be available...
# 10  Name of Tournament should be available to the ...
# 11  Starting and ending date of tournament should ...
# 12  Each team players will have Names, Contacts nu...
# 13   The website shall assign the user a specific ID.
# 14  Each player will have their own FirstName Last...
# 15  Each Players will have their own specific play...
# 16  The website shall enable to store the Roles (B...
# 17  The website will also store the Date of the to...
# 18  Every Match Detail will have a specific Match ...
# 19  Every Match will have a specific scorecard whi...
# 20  The Match Scorecard will contain the total run...
#
#                      Requirement with Standard Syntax        type Domain  \
# 0   The game shall be developed using unity game e...  ubiquitous   Game
# 1   The game shall be written in C# and use Unity ...  ubiquitous   Game
# 2   The Game shall feature accurate sound effects ...  ubiquitous   Game
# 3   The game shall be playable using mouse and key...  ubiquitous   Game
# 4   The Game shall offer a compelling story which ...  ubiquitous   Game
# 5   The Game shall implement AI for the enemies an...  ubiquitous   Game
# 6   The Game shall challenge the user to think and...  ubiquitous   Game
# 7         The system shall allow the user to register  ubiquitous   Game
# 8            The system shall provide a login option.  ubiquitous   Game
# 9   the System shall provide the Request Cricket T...  ubiquitous   Game
# 10   The system shall provide the Name of Tournament.  ubiquitous   Game
# 11  The system shall provide starting and ending d...  ubiquitous   Game
# 12  the  team players shall have Names, Contacts n...  ubiquitous   Game
# 13    The system shall assign the user a specific ID.  ubiquitous   Game
# 14  The system shall allow the player to enter the...  ubiquitous   Game
# 15  The system shall provide the specific player i...  ubiquitous   Game
# 16  The system shall store the Roles (Batsmen/bowl...  ubiquitous   Game
# 17  The system shall store the Date of the tournam...  ubiquitous   Game
# 18  The system shall provide a specific ID to ever...  ubiquitous   Game
# 19  The system shall be able to  have a specific s...  ubiquitous   Game
# 20  The system shall have the match scorecard whic...  ubiquitous   Game
#
#     sub_domain  raw_length  standard_length
# 0   Mobile app          54               51
# 1   Mobile app         100               74
# 2   Mobile app          92               93
# 3   Mobile app          59               52
# 4   Mobile app          89               90
# 5   Mobile app          81               82
# 6   Mobile app          83               84
# 7   Mobile app          54               43
# 8   Mobile app          40               40
# 9   Mobile app          59               68
# 10  Mobile app          52               48
# 11  Mobile app          58               64
# 12  Mobile app          72               73
# 13  Mobile app          48               47
# 14  Mobile app          84              113
# 15  Mobile app          64               76
# 16  Mobile app          75               64
# 17  Mobile app          61               56
# 18  Mobile app          55               61
# 19  Mobile app          84               96
# 20  Mobile app          69               93

# %%
import nltk
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\WB\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
data['Raw Requirements'] = data['Raw Requirements'].str.lower()
data['Raw Requirements'] = data['Raw Requirements'].str.replace(r'^.+@[^\.].*\.[a-z]{2,}$', 'emailaddress')
data['Raw Requirements'] = data['Raw Requirements'].str.replace(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$', 'webaddress')
data['Raw Requirements'] = data['Raw Requirements'].str.replace(r'£|\$', 'dollers')
data['Raw Requirements'] = data['Raw Requirements'].str.replace(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$', 'phonenumber')
data['Raw Requirements'] = data['Raw Requirements'].str.replace(r'\d+(\.\d+)?', 'numbr')
data['Raw Requirements'] = data['Raw Requirements'].apply(lambda x: ' '.join(term for term in x.split() if term not in string.punctuation))
stop_words = set(stopwords.words('english') + ['u', 'ü', 'ur', '4', '2', 'im', 'dont', 'doin', 'ure'])
data['Raw Requirements'] = data['Raw Requirements'].apply(lambda x: ' '.join(term for term in x.split() if term not in stop_words))
lemmatizer = WordNetLemmatizer()
data['Raw Requirements'] = data['Raw Requirements'].apply(lambda x: ' '.join(lemmatizer.lemmatize(t) for t in x.split()))

# first we convert all the words to lower case
# then we replace the email addresses, urls, phone numbers, currency symbols and numbers with their respective words to remove special characters
# stopwords are the words which do not add any meaning to a sentence like the, is, at, which, and etc and we are removing them
# then we remove the punctuation and the stop words and then we lemmatize the words

# %%
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].str.lower()
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].str.replace(r'^.+@[^\.].*\.[a-z]{2,}$', 'emailaddress')
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].str.replace(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$', 'webaddress')
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].str.replace(r'£|\$', 'dollers')
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].str.replace(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$', 'phonenumber')
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].str.replace(r'\d+(\.\d+)?', 'numbr')
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].apply(lambda x: ' '.join(term for term in x.split() if term not in string.punctuation))
stop_words = set(stopwords.words('english') + ['u', 'ü', 'ur', '4', '2', 'im', 'dont', 'doin', 'ure'])
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].apply(lambda x: ' '.join(term for term in x.split() if term not in stop_words))
lemmatizer = WordNetLemmatizer()
data['Requirement with Standard Syntax'] = data['Requirement with Standard Syntax'].apply(lambda x: ' '.join(lemmatizer.lemmatize(t) for t in x.split()))

# %%
data['clean_raw_length'] = data['Raw Requirements'].str.len()
data['clean_standard_length'] = data['Requirement with Standard Syntax'].str.len()
data
# Out:
#                                      Raw Requirements  \
# 0         game must developed using unity game engine
# 1   game must programmed using c# language library...
# 2   game must feature accurate sound effect music ...
# 3         game must playable using keyboard key mouse
# 4   game must offer compelling story convey specia...
# 5   game must implement ai enemy npc offer complet...
# 6   game must challenge user think build strategy ...
# 7                    user shall able register system.
# 8                             login available website
# 9          request cricket tournament available user.
# 10                   name tournament available system
# 11          starting ending date tournament available
# 12        team player names, contact number city name
# 13             website shall assign user specific id.
# 14  player firstname lastname dob email contact ci...
# 15                 player specific player id team id.
# 16  website shall enable store role (batsmen/bowle...
# 17          website also store date tournament match.
# 18        every match detail specific match detail id
# 19  every match specific scorecard access match de...
# 20   match scorecard contain total run specific match
#
#                      Requirement with Standard Syntax        type Domain  \
# 0        game shall developed using unity game engine  ubiquitous   Game
# 1   game shall written c# use unity engine-compati...  ubiquitous   Game
# 2   game shall feature accurate sound effect music...  ubiquitous   Game
# 3           game shall playable using mouse keyboard.  ubiquitous   Game
# 4   game shall offer compelling story convey speci...  ubiquitous   Game
# 5   game shall implement ai enemy npc offer comple...  ubiquitous   Game
# 6   game shall challenge user think build strategy...  ubiquitous   Game
# 7                    system shall allow user register  ubiquitous   Game
# 8                  system shall provide login option.  ubiquitous   Game
# 9   system shall provide request cricket tournamen...  ubiquitous   Game
# 10              system shall provide name tournament.  ubiquitous   Game
# 11  system shall provide starting ending date tour...  ubiquitous   Game
# 12  team player shall names, contact number city name  ubiquitous   Game
# 13              system shall assign user specific id.  ubiquitous   Game
# 14  system shall allow player enter first name, la...  ubiquitous   Game
# 15  system shall provide specific player id team i...  ubiquitous   Game
# 16   system shall store role (batsmen/bowler) player.  ubiquitous   Game
# 17          system shall store date tournament match.  ubiquitous   Game
# 18  system shall provide specific id every match d...  ubiquitous   Game
# 19  system shall able specific scorecard access ma...  ubiquitous   Game
# 20  system shall match scorecard contain total run...  ubiquitous   Game
#
#     sub_domain  raw_length  standard_length  clean_raw_length  \
# 0   Mobile app          54               51                43
# 1   Mobile app         100               74                70
# 2   Mobile app          92               93                74
# 3   Mobile app          59               52                43
# 4   Mobile app          89               90                62
# 5   Mobile app          81               82                58
# 6   Mobile app          83               84                59
# 7   Mobile app          54               43                32
# 8   Mobile app          40               40                23
# 9   Mobile app          59               68                42
# 10  Mobile app          52               48                32
# 11  Mobile app          58               64                41
# 12  Mobile app          72               73                43
# 13  Mobile app          48               47                38
# 14  Mobile app          84              113                56
# 15  Mobile app          64               76                34
# 16  Mobile app          75               64                56
# 17  Mobile app          61               56                41
# 18  Mobile app          55               61                43
# 19  Mobile app          84               96                50
# 20  Mobile app          69               93                48
#
#     clean_standard_length
# 0                      44
# 1                      60
# 2                      75
# 3                      41
# 4                      63
# 5                      59
# 6                      60
# 7                      32
# 8                      34
# 9                      53
# 10                     37
# 11                     53
# 12                     49
# 13                     37
# 14                     92
# 15                     56
# 16                     48
# 17                     41
# 18                     52
# 19                     56
# 20                     62

# %%
print ('Origian Raw Requirements Length', data['raw_length'].sum())
print ('Clean Raw Requirements Length', data['clean_raw_length'].sum())
print ('Origian Requirement with Standard Syntax', data['standard_length'].sum())
print ('Clean Requirement with Standard Syntax', data['clean_standard_length'].sum())
# Out:
# Origian Raw Requirements Length 1433
# Clean Raw Requirements Length 988
# Origian Requirement with Standard Syntax 1468
# Clean Requirement with Standard Syntax 1104

# %%
data[' type'].value_counts()
# printing the number of requirements in each type (column name is type)
# Out:
# ubiquitous    21
# Name:  type, dtype: int64

# %%
data.reset_index(inplace=True)

# %%
for i in range(len(data[' type'])):
    str = data[' type'][i]
    if 'state' in str:
        data[' type'][i] = 'state-driven'
    elif 'eve' in str:
        data[' type'][i] = 'event-driven'
    elif 'biquit' in str:
        data[' type'][i] = 'ubiquitous'
    elif 'wanted' in str:
        data[' type'][i] = 'unwanted-behaviour'
    elif 'tional' in str:
        data[' type'][i] = 'optional-feature'

# %%
data[' type'].value_counts()
# Out:
# ubiquitous    21
# Name:  type, dtype: int64

# %%
data[' type'] = data[' type'].map({'ubiquitous':0, 'state-driven':1, 'event-driven':2, 'unwanted-behaviour':3, 'optional-feature':4})
# assigning the numbers to the types and storing them in the same column
# for example ubiquitous is assigned 0, state-driven is assigned 1 and so on
data
# Out:
#     index                                   Raw Requirements  \
# 0       0        game must developed using unity game engine
# 1       1  game must programmed using c# language library...
# 2       2  game must feature accurate sound effect music ...
# 3       3        game must playable using keyboard key mouse
# 4       4  game must offer compelling story convey specia...
# 5       5  game must implement ai enemy npc offer complet...
# 6       6  game must challenge user think build strategy ...
# 7       7                   user shall able register system.
# 8       8                            login available website
# 9       9         request cricket tournament available user.
# 10     10                   name tournament available system
# 11     11          starting ending date tournament available
# 12     12        team player names, contact number city name
# 13     13             website shall assign user specific id.
# 14     14  player firstname lastname dob email contact ci...
# 15     15                 player specific player id team id.
# 16     16  website shall enable store role (batsmen/bowle...
# 17     17          website also store date tournament match.
# 18     18        every match detail specific match detail id
# 19     19  every match specific scorecard access match de...
# 20     20   match scorecard contain total run specific match
#
#                      Requirement with Standard Syntax   type Domain  \
# 0        game shall developed using unity game engine      0   Game
# 1   game shall written c# use unity engine-compati...      0   Game
# 2   game shall feature accurate sound effect music...      0   Game
# 3           game shall playable using mouse keyboard.      0   Game
# 4   game shall offer compelling story convey speci...      0   Game
# 5   game shall implement ai enemy npc offer comple...      0   Game
# 6   game shall challenge user think build strategy...      0   Game
# 7                    system shall allow user register      0   Game
# 8                  system shall provide login option.      0   Game
# 9   system shall provide request cricket tournamen...      0   Game
# 10              system shall provide name tournament.      0   Game
# 11  system shall provide starting ending date tour...      0   Game
# 12  team player shall names, contact number city name      0   Game
# 13              system shall assign user specific id.      0   Game
# 14  system shall allow player enter first name, la...      0   Game
# 15  system shall provide specific player id team i...      0   Game
# 16   system shall store role (batsmen/bowler) player.      0   Game
# 17          system shall store date tournament match.      0   Game
# 18  system shall provide specific id every match d...      0   Game
# 19  system shall able specific scorecard access ma...      0   Game
# 20  system shall match scorecard contain total run...      0   Game
#
#     sub_domain  raw_length  standard_length  clean_raw_length  \
# 0   Mobile app          54               51                43
# 1   Mobile app         100               74                70
# 2   Mobile app          92               93                74
# 3   Mobile app          59               52                43
# 4   Mobile app          89               90                62
# 5   Mobile app          81               82                58
# 6   Mobile app          83               84                59
# 7   Mobile app          54               43                32
# 8   Mobile app          40               40                23
# 9   Mobile app          59               68                42
# 10  Mobile app          52               48                32
# 11  Mobile app          58               64                41
# 12  Mobile app          72               73                43
# 13  Mobile app          48               47                38
# 14  Mobile app          84              113                56
# 15  Mobile app          64               76                34
# 16  Mobile app          75               64                56
# 17  Mobile app          61               56                41
# 18  Mobile app          55               61                43
# 19  Mobile app          84               96                50
# 20  Mobile app          69               93                48
#
#     clean_standard_length
# 0                      44
# 1                      60
# 2                      75
# 3                      41
# 4                      63
# 5                      59
# 6                      60
# 7                      32
# 8                      34
# 9                      53
# 10                     37
# 11                     53
# 12                     49
# 13                     37
# 14                     92
# 15                     56
# 16                     48
# 17                     41
# 18                     52
# 19                     56
# 20                     62

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# punkt is a pre-trained tokenizer for english language and averaged_perceptron_tagger is a pre-trained part-of-speech tagger for english language
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\WB\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\WB\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from collections import Counter
from nltk import word_tokenize, pos_tag, pos_tag_sents
texts=data['Raw Requirements'].tolist()
tagged_texts = pos_tag_sents(map(word_tokenize, texts))
# pos_tag_sents is a function which takes a list of sentences and returns a list of tuples where each tuple contains a word and its part-of-speech tag

# for example from sentence "game must developed using unity game engine" we get the following list of tuples
# [('game', 'NN'), ('must', 'MD'), ('developed', 'VBN'), ('using', 'VBG'), ('unity', 'NN'), ('game', 'NN'), ('engine', 'NN')]
# where NN is noun, 
# MD is modal verb (modal verbs are can, could, may, might, must, will, would, shall, should, and needn't),
# VBN is past participle 
# VBG is gerund
tagged_texts

data['POS'] = tagged_texts
data
# Out:
#     index                                   Raw Requirements  \
# 0       0        game must developed using unity game engine
# 1       1  game must programmed using c# language library...
# 2       2  game must feature accurate sound effect music ...
# 3       3        game must playable using keyboard key mouse
# 4       4  game must offer compelling story convey specia...
# 5       5  game must implement ai enemy npc offer complet...
# 6       6  game must challenge user think build strategy ...
# 7       7                   user shall able register system.
# 8       8                            login available website
# 9       9         request cricket tournament available user.
# 10     10                   name tournament available system
# 11     11          starting ending date tournament available
# 12     12        team player names, contact number city name
# 13     13             website shall assign user specific id.
# 14     14  player firstname lastname dob email contact ci...
# 15     15                 player specific player id team id.
# 16     16  website shall enable store role (batsmen/bowle...
# 17     17          website also store date tournament match.
# 18     18        every match detail specific match detail id
# 19     19  every match specific scorecard access match de...
# 20     20   match scorecard contain total run specific match
#
#                      Requirement with Standard Syntax   type Domain  \
# 0        game shall developed using unity game engine      0   Game
# 1   game shall written c# use unity engine-compati...      0   Game
# 2   game shall feature accurate sound effect music...      0   Game
# 3           game shall playable using mouse keyboard.      0   Game
# 4   game shall offer compelling story convey speci...      0   Game
# 5   game shall implement ai enemy npc offer comple...      0   Game
# 6   game shall challenge user think build strategy...      0   Game
# 7                    system shall allow user register      0   Game
# 8                  system shall provide login option.      0   Game
# 9   system shall provide request cricket tournamen...      0   Game
# 10              system shall provide name tournament.      0   Game
# 11  system shall provide starting ending date tour...      0   Game
# 12  team player shall names, contact number city name      0   Game
# 13              system shall assign user specific id.      0   Game
# 14  system shall allow player enter first name, la...      0   Game
# 15  system shall provide specific player id team i...      0   Game
# 16   system shall store role (batsmen/bowler) player.      0   Game
# 17          system shall store date tournament match.      0   Game
# 18  system shall provide specific id every match d...      0   Game
# 19  system shall able specific scorecard access ma...      0   Game
# 20  system shall match scorecard contain total run...      0   Game
#
#     sub_domain  raw_length  standard_length  clean_raw_length  \
# 0   Mobile app          54               51                43
# 1   Mobile app         100               74                70
# 2   Mobile app          92               93                74
# 3   Mobile app          59               52                43
# 4   Mobile app          89               90                62
# 5   Mobile app          81               82                58
# 6   Mobile app          83               84                59
# 7   Mobile app          54               43                32
# 8   Mobile app          40               40                23
# 9   Mobile app          59               68                42
# 10  Mobile app          52               48                32
# 11  Mobile app          58               64                41
# 12  Mobile app          72               73                43
# 13  Mobile app          48               47                38
# 14  Mobile app          84              113                56
# 15  Mobile app          64               76                34
# 16  Mobile app          75               64                56
# 17  Mobile app          61               56                41
# 18  Mobile app          55               61                43
# 19  Mobile app          84               96                50
# 20  Mobile app          69               93                48
#
#     clean_standard_length                                                POS
# 0                      44  [(game, NN), (must, MD), (developed, VB), (usi...
# 1                      60  [(game, NN), (must, MD), (programmed, VB), (us...
# 2                      75  [(game, NN), (must, MD), (feature, VB), (accur...
# 3                      41  [(game, NN), (must, MD), (playable, VB), (usin...
# 4                      63  [(game, NN), (must, MD), (offer, VB), (compell...
# 5                      59  [(game, NN), (must, MD), (implement, VB), (ai,...
# 6                      60  [(game, NN), (must, MD), (challenge, VB), (use...
# 7                      32  [(user, RB), (shall, MD), (able, JJ), (registe...
# 8                      34      [(login, NN), (available, JJ), (website, NN)]
# 9                      53  [(request, NN), (cricket, NN), (tournament, NN...
# 10                     37  [(name, NN), (tournament, NN), (available, JJ)...
# 11                     53  [(starting, VBG), (ending, VBG), (date, NN), (...
# 12                     49  [(team, NN), (player, NN), (names, NNS), (,, ,...
# 13                     37  [(website, JJ), (shall, MD), (assign, VB), (us...
# 14                     92  [(player, NN), (firstname, NN), (lastname, NN)...
# 15                     56  [(player, NN), (specific, JJ), (player, NN), (...
# 16                     48  [(website, JJ), (shall, MD), (enable, VB), (st...
# 17                     41  [(website, NN), (also, RB), (store, NN), (date...
# 18                     52  [(every, DT), (match, NN), (detail, NN), (spec...
# 19                     56  [(every, DT), (match, NN), (specific, JJ), (sc...
# 20                     62  [(match, NN), (scorecard, NN), (contain, VBP),...

# %%
dataa = data[['index', 'POS']].copy()
# creating a new dataframe with only the index and POS columns

# %%
dataa
# Out:
#     index                                                POS
# 0       0  [(game, NN), (must, MD), (developed, VB), (usi...
# 1       1  [(game, NN), (must, MD), (programmed, VB), (us...
# 2       2  [(game, NN), (must, MD), (feature, VB), (accur...
# 3       3  [(game, NN), (must, MD), (playable, VB), (usin...
# 4       4  [(game, NN), (must, MD), (offer, VB), (compell...
# 5       5  [(game, NN), (must, MD), (implement, VB), (ai,...
# 6       6  [(game, NN), (must, MD), (challenge, VB), (use...
# 7       7  [(user, RB), (shall, MD), (able, JJ), (registe...
# 8       8      [(login, NN), (available, JJ), (website, NN)]
# 9       9  [(request, NN), (cricket, NN), (tournament, NN...
# 10     10  [(name, NN), (tournament, NN), (available, JJ)...
# 11     11  [(starting, VBG), (ending, VBG), (date, NN), (...
# 12     12  [(team, NN), (player, NN), (names, NNS), (,, ,...
# 13     13  [(website, JJ), (shall, MD), (assign, VB), (us...
# 14     14  [(player, NN), (firstname, NN), (lastname, NN)...
# 15     15  [(player, NN), (specific, JJ), (player, NN), (...
# 16     16  [(website, JJ), (shall, MD), (enable, VB), (st...
# 17     17  [(website, NN), (also, RB), (store, NN), (date...
# 18     18  [(every, DT), (match, NN), (detail, NN), (spec...
# 19     19  [(every, DT), (match, NN), (specific, JJ), (sc...
# 20     20  [(match, NN), (scorecard, NN), (contain, VBP),...

# %%
data
# Out:
#     index                                   Raw Requirements  \
# 0       0        game must developed using unity game engine
# 1       1  game must programmed using c# language library...
# 2       2  game must feature accurate sound effect music ...
# 3       3        game must playable using keyboard key mouse
# 4       4  game must offer compelling story convey specia...
# 5       5  game must implement ai enemy npc offer complet...
# 6       6  game must challenge user think build strategy ...
# 7       7                   user shall able register system.
# 8       8                            login available website
# 9       9         request cricket tournament available user.
# 10     10                   name tournament available system
# 11     11          starting ending date tournament available
# 12     12        team player names, contact number city name
# 13     13             website shall assign user specific id.
# 14     14  player firstname lastname dob email contact ci...
# 15     15                 player specific player id team id.
# 16     16  website shall enable store role (batsmen/bowle...
# 17     17          website also store date tournament match.
# 18     18        every match detail specific match detail id
# 19     19  every match specific scorecard access match de...
# 20     20   match scorecard contain total run specific match
#
#                      Requirement with Standard Syntax   type Domain  \
# 0        game shall developed using unity game engine      0   Game
# 1   game shall written c# use unity engine-compati...      0   Game
# 2   game shall feature accurate sound effect music...      0   Game
# 3           game shall playable using mouse keyboard.      0   Game
# 4   game shall offer compelling story convey speci...      0   Game
# 5   game shall implement ai enemy npc offer comple...      0   Game
# 6   game shall challenge user think build strategy...      0   Game
# 7                    system shall allow user register      0   Game
# 8                  system shall provide login option.      0   Game
# 9   system shall provide request cricket tournamen...      0   Game
# 10              system shall provide name tournament.      0   Game
# 11  system shall provide starting ending date tour...      0   Game
# 12  team player shall names, contact number city name      0   Game
# 13              system shall assign user specific id.      0   Game
# 14  system shall allow player enter first name, la...      0   Game
# 15  system shall provide specific player id team i...      0   Game
# 16   system shall store role (batsmen/bowler) player.      0   Game
# 17          system shall store date tournament match.      0   Game
# 18  system shall provide specific id every match d...      0   Game
# 19  system shall able specific scorecard access ma...      0   Game
# 20  system shall match scorecard contain total run...      0   Game
#
#     sub_domain  raw_length  standard_length  clean_raw_length  \
# 0   Mobile app          54               51                43
# 1   Mobile app         100               74                70
# 2   Mobile app          92               93                74
# 3   Mobile app          59               52                43
# 4   Mobile app          89               90                62
# 5   Mobile app          81               82                58
# 6   Mobile app          83               84                59
# 7   Mobile app          54               43                32
# 8   Mobile app          40               40                23
# 9   Mobile app          59               68                42
# 10  Mobile app          52               48                32
# 11  Mobile app          58               64                41
# 12  Mobile app          72               73                43
# 13  Mobile app          48               47                38
# 14  Mobile app          84              113                56
# 15  Mobile app          64               76                34
# 16  Mobile app          75               64                56
# 17  Mobile app          61               56                41
# 18  Mobile app          55               61                43
# 19  Mobile app          84               96                50
# 20  Mobile app          69               93                48
#
#     clean_standard_length                                                POS
# 0                      44  [(game, NN), (must, MD), (developed, VB), (usi...
# 1                      60  [(game, NN), (must, MD), (programmed, VB), (us...
# 2                      75  [(game, NN), (must, MD), (feature, VB), (accur...
# 3                      41  [(game, NN), (must, MD), (playable, VB), (usin...
# 4                      63  [(game, NN), (must, MD), (offer, VB), (compell...
# 5                      59  [(game, NN), (must, MD), (implement, VB), (ai,...
# 6                      60  [(game, NN), (must, MD), (challenge, VB), (use...
# 7                      32  [(user, RB), (shall, MD), (able, JJ), (registe...
# 8                      34      [(login, NN), (available, JJ), (website, NN)]
# 9                      53  [(request, NN), (cricket, NN), (tournament, NN...
# 10                     37  [(name, NN), (tournament, NN), (available, JJ)...
# 11                     53  [(starting, VBG), (ending, VBG), (date, NN), (...
# 12                     49  [(team, NN), (player, NN), (names, NNS), (,, ,...
# 13                     37  [(website, JJ), (shall, MD), (assign, VB), (us...
# 14                     92  [(player, NN), (firstname, NN), (lastname, NN)...
# 15                     56  [(player, NN), (specific, JJ), (player, NN), (...
# 16                     48  [(website, JJ), (shall, MD), (enable, VB), (st...
# 17                     41  [(website, NN), (also, RB), (store, NN), (date...
# 18                     52  [(every, DT), (match, NN), (detail, NN), (spec...
# 19                     56  [(every, DT), (match, NN), (specific, JJ), (sc...
# 20                     62  [(match, NN), (scorecard, NN), (contain, VBP),...

# %%
dataa['Nouns'] = 'a'
dataa['Verbs'] = 'b'
dataa['Adjectives']='c'
dataa['Boilerplate']='d'

# %%
dataa
# Out:
#     index                                                POS Nouns Verbs  \
# 0       0  [(game, NN), (must, MD), (developed, VB), (usi...     a     b
# 1       1  [(game, NN), (must, MD), (programmed, VB), (us...     a     b
# 2       2  [(game, NN), (must, MD), (feature, VB), (accur...     a     b
# 3       3  [(game, NN), (must, MD), (playable, VB), (usin...     a     b
# 4       4  [(game, NN), (must, MD), (offer, VB), (compell...     a     b
# 5       5  [(game, NN), (must, MD), (implement, VB), (ai,...     a     b
# 6       6  [(game, NN), (must, MD), (challenge, VB), (use...     a     b
# 7       7  [(user, RB), (shall, MD), (able, JJ), (registe...     a     b
# 8       8      [(login, NN), (available, JJ), (website, NN)]     a     b
# 9       9  [(request, NN), (cricket, NN), (tournament, NN...     a     b
# 10     10  [(name, NN), (tournament, NN), (available, JJ)...     a     b
# 11     11  [(starting, VBG), (ending, VBG), (date, NN), (...     a     b
# 12     12  [(team, NN), (player, NN), (names, NNS), (,, ,...     a     b
# 13     13  [(website, JJ), (shall, MD), (assign, VB), (us...     a     b
# 14     14  [(player, NN), (firstname, NN), (lastname, NN)...     a     b
# 15     15  [(player, NN), (specific, JJ), (player, NN), (...     a     b
# 16     16  [(website, JJ), (shall, MD), (enable, VB), (st...     a     b
# 17     17  [(website, NN), (also, RB), (store, NN), (date...     a     b
# 18     18  [(every, DT), (match, NN), (detail, NN), (spec...     a     b
# 19     19  [(every, DT), (match, NN), (specific, JJ), (sc...     a     b
# 20     20  [(match, NN), (scorecard, NN), (contain, VBP),...     a     b
#
#    Adjectives Boilerplate
# 0           c           d
# 1           c           d
# 2           c           d
# 3           c           d
# 4           c           d
# 5           c           d
# 6           c           d
# 7           c           d
# 8           c           d
# 9           c           d
# 10          c           d
# 11          c           d
# 12          c           d
# 13          c           d
# 14          c           d
# 15          c           d
# 16          c           d
# 17          c           d
# 18          c           d
# 19          c           d
# 20          c           d

# %% [markdown]
# **Extract** ,**Nouns** **Verbs** **and** **Adjectives***

# %%
print(data['POS'][0][0][1])
# Out:
# NN

# %%
print(len(data['POS'][0]))
# Out:
# 7

# %%
for s in range(len(data['POS'][0])):
    if data['POS'][0][s][1]=='NN':
        print(data['POS'][0][s][0])
# Out:
# game
# game
# engine

# %%
for s in range(len(data['POS'][0])):
    if data['POS'][0][s][1]=='VB':
        print(data['POS'][0][s][0])
# Out:
# developed

# %%
for s in range(len(data['POS'][0])):
    if data['POS'][0][s][1]=='JJ':
        print(data['POS'][0][s][0])
# Out:
# unity

# %%
nouns = []
for s in range(len(data['POS'][0])):
    if data['POS'][0][s][1]=='NN':
        if data['POS'][0][s][0] not in nouns:
            nouns.append(data['POS'][0][s][0])

# %%
verbs = []
for s in range(len(data['POS'][0])):
    if data['POS'][0][s][1]=='VB':
        if data['POS'][0][s][0] not in verbs:
            verbs.append(data['POS'][0][s][0])

# %%
adjective = []
for s in range(len(data['POS'][0])):
    if data['POS'][0][s][1]=='JJ':
        if data['POS'][0][s][0] not in adjective:
            adjective.append(data['POS'][0][s][0])

# %%
nouns
# Out:
# ['game', 'engine']

# %%
verbs
# Out:
# ['developed']

# %%
adjective
# Out:
# ['unity']

# %%
dataa.at[0, 'Nouns'] = nouns

# %%
dataa.at[0, 'Verbs'] = verbs

# %%
dataa.at[0, 'Adjectives'] = adjective

# %%
len(data['POS'])
# Out:
# 21

# %%
for t in range(len(data['POS'])):
    nouns = []
    for s in range(len(data['POS'][t])):
        if data['POS'][t][s][1]=='NN':
            if data['POS'][t][s][0] not in nouns:
                nouns.append(data['POS'][t][s][0])
    dataa.at[t, 'Nouns'] = nouns

# %%
for t in range(len(data['POS'])):
    verbs = []
    for s in range(len(data['POS'][t])):
        if 'VB' in data['POS'][t][s][1]:
            if data['POS'][t][s][0] not in verbs:
                verbs.append(data['POS'][t][s][0])
    dataa.at[t, 'Verbs'] = verbs

# %%
for t in range(len(data['POS'])):
    adjective = []
    for s in range(len(data['POS'][t])):
        if data['POS'][t][s][1]=='JJ':
            if data['POS'][t][s][0] not in adjective:
                adjective.append(data['POS'][t][s][0])
    dataa.at[t, 'Adjectives'] = adjective

# %%
len(nouns)
# Out:
# 3

# %%
len(verbs)
# Out:
# 1

# %%
len(adjective)
# Out:
# 2

# %%
print(nouns)
# Out:
# ['match', 'scorecard', 'run']

# %%
print(verbs)
# Out:
# ['contain']

# %%
print(adjective)
# Out:
# ['total', 'specific']

# %%
dataa
# Out:
#     index                                                POS  \
# 0       0  [(game, NN), (must, MD), (developed, VB), (usi...
# 1       1  [(game, NN), (must, MD), (programmed, VB), (us...
# 2       2  [(game, NN), (must, MD), (feature, VB), (accur...
# 3       3  [(game, NN), (must, MD), (playable, VB), (usin...
# 4       4  [(game, NN), (must, MD), (offer, VB), (compell...
# 5       5  [(game, NN), (must, MD), (implement, VB), (ai,...
# 6       6  [(game, NN), (must, MD), (challenge, VB), (use...
# 7       7  [(user, RB), (shall, MD), (able, JJ), (registe...
# 8       8      [(login, NN), (available, JJ), (website, NN)]
# 9       9  [(request, NN), (cricket, NN), (tournament, NN...
# 10     10  [(name, NN), (tournament, NN), (available, JJ)...
# 11     11  [(starting, VBG), (ending, VBG), (date, NN), (...
# 12     12  [(team, NN), (player, NN), (names, NNS), (,, ,...
# 13     13  [(website, JJ), (shall, MD), (assign, VB), (us...
# 14     14  [(player, NN), (firstname, NN), (lastname, NN)...
# 15     15  [(player, NN), (specific, JJ), (player, NN), (...
# 16     16  [(website, JJ), (shall, MD), (enable, VB), (st...
# 17     17  [(website, NN), (also, RB), (store, NN), (date...
# 18     18  [(every, DT), (match, NN), (detail, NN), (spec...
# 19     19  [(every, DT), (match, NN), (specific, JJ), (sc...
# 20     20  [(match, NN), (scorecard, NN), (contain, VBP),...
#
#                                                 Nouns                Verbs  \
# 0                                      [game, engine]   [developed, using]
# 1                     [game, language, unity, engine]  [programmed, using]
# 2                      [game, effect, music, conveys]            [feature]
# 3                                  [game, key, mouse]    [playable, using]
# 4              [game, story, convey, message, player]  [offer, compelling]
# 5                      [game, enemy, npc, experience]   [implement, offer]
# 6                             [game, think, strategy]   [challenge, build]
# 7                                  [register, system]                   []
# 8                                    [login, website]                   []
# 9                [request, cricket, tournament, user]                   []
# 10                         [name, tournament, system]                   []
# 11                                 [date, tournament]   [starting, ending]
# 12                 [team, player, number, city, name]                   []
# 13                                               [id]             [assign]
# 14  [player, firstname, lastname, contact, city, a...                   []
# 15                                 [player, id, team]                   []
# 16              [store, role, batsmen/bowler, player]             [enable]
# 17          [website, store, date, tournament, match]                   []
# 18                                [match, detail, id]                   []
# 19                            [match, access, detail]                   []
# 20                            [match, scorecard, run]            [contain]
#
#                    Adjectives Boilerplate
# 0                     [unity]           d
# 1    [c, library, compatible]           d
# 2           [accurate, sound]           d
# 3                  [keyboard]           d
# 4                   [special]           d
# 5              [ai, complete]           d
# 6            [user, complete]           d
# 7                      [able]           d
# 8                 [available]           d
# 9                 [available]           d
# 10                [available]           d
# 11                [available]           d
# 12                  [contact]           d
# 13  [website, user, specific]           d
# 14               [dob, email]           d
# 15                 [specific]           d
# 16                  [website]           d
# 17                         []           d
# 18                 [specific]           d
# 19      [specific, scorecard]           d
# 20          [total, specific]           d

# %%
arr = []
for i in range(len(dataa)):
    verbs = ' '.join(dataa.iloc[i]['Verbs'])
    nouns = ' '.join(dataa.iloc[i]['Adjectives'])
    adjectives = ' '.join(dataa.iloc[i]['Nouns'])
    str = 'The system shall ' + verbs + ' ' + nouns + ' ' + adjectives
    arr.append(str)
arr
# Out:
# ['The system shall developed using unity game engine',
#  'The system shall programmed using c library compatible game language unity engine',
#  'The system shall feature accurate sound game effect music conveys',
#  'The system shall playable using keyboard game key mouse',
#  'The system shall offer compelling special game story convey message player',
#  'The system shall implement offer ai complete game enemy npc experience',
#  'The system shall challenge build user complete game think strategy',
#  'The system shall  able register system',
#  'The system shall  available login website',
#  'The system shall  available request cricket tournament user',
#  'The system shall  available name tournament system',
#  'The system shall starting ending available date tournament',
#  'The system shall  contact team player number city name',
#  'The system shall assign website user specific id',
#  'The system shall  dob email player firstname lastname contact city address',
#  'The system shall  specific player id team',
#  'The system shall enable website store role batsmen/bowler player',
#  'The system shall   website store date tournament match',
#  'The system shall  specific match detail id',
#  'The system shall  specific scorecard match access detail',
#  'The system shall contain total specific match scorecard run']

# %% [markdown]
# **Boilerplate**

# %%
data['Boilerplate Sentence'] = arr
data
# Out:
#     index                                   Raw Requirements  \
# 0       0        game must developed using unity game engine
# 1       1  game must programmed using c# language library...
# 2       2  game must feature accurate sound effect music ...
# 3       3        game must playable using keyboard key mouse
# 4       4  game must offer compelling story convey specia...
# 5       5  game must implement ai enemy npc offer complet...
# 6       6  game must challenge user think build strategy ...
# 7       7                   user shall able register system.
# 8       8                            login available website
# 9       9         request cricket tournament available user.
# 10     10                   name tournament available system
# 11     11          starting ending date tournament available
# 12     12        team player names, contact number city name
# 13     13             website shall assign user specific id.
# 14     14  player firstname lastname dob email contact ci...
# 15     15                 player specific player id team id.
# 16     16  website shall enable store role (batsmen/bowle...
# 17     17          website also store date tournament match.
# 18     18        every match detail specific match detail id
# 19     19  every match specific scorecard access match de...
# 20     20   match scorecard contain total run specific match
#
#                      Requirement with Standard Syntax   type Domain  \
# 0        game shall developed using unity game engine      0   Game
# 1   game shall written c# use unity engine-compati...      0   Game
# 2   game shall feature accurate sound effect music...      0   Game
# 3           game shall playable using mouse keyboard.      0   Game
# 4   game shall offer compelling story convey speci...      0   Game
# 5   game shall implement ai enemy npc offer comple...      0   Game
# 6   game shall challenge user think build strategy...      0   Game
# 7                    system shall allow user register      0   Game
# 8                  system shall provide login option.      0   Game
# 9   system shall provide request cricket tournamen...      0   Game
# 10              system shall provide name tournament.      0   Game
# 11  system shall provide starting ending date tour...      0   Game
# 12  team player shall names, contact number city name      0   Game
# 13              system shall assign user specific id.      0   Game
# 14  system shall allow player enter first name, la...      0   Game
# 15  system shall provide specific player id team i...      0   Game
# 16   system shall store role (batsmen/bowler) player.      0   Game
# 17          system shall store date tournament match.      0   Game
# 18  system shall provide specific id every match d...      0   Game
# 19  system shall able specific scorecard access ma...      0   Game
# 20  system shall match scorecard contain total run...      0   Game
#
#     sub_domain  raw_length  standard_length  clean_raw_length  \
# 0   Mobile app          54               51                43
# 1   Mobile app         100               74                70
# 2   Mobile app          92               93                74
# 3   Mobile app          59               52                43
# 4   Mobile app          89               90                62
# 5   Mobile app          81               82                58
# 6   Mobile app          83               84                59
# 7   Mobile app          54               43                32
# 8   Mobile app          40               40                23
# 9   Mobile app          59               68                42
# 10  Mobile app          52               48                32
# 11  Mobile app          58               64                41
# 12  Mobile app          72               73                43
# 13  Mobile app          48               47                38
# 14  Mobile app          84              113                56
# 15  Mobile app          64               76                34
# 16  Mobile app          75               64                56
# 17  Mobile app          61               56                41
# 18  Mobile app          55               61                43
# 19  Mobile app          84               96                50
# 20  Mobile app          69               93                48
#
#     clean_standard_length                                                POS  \
# 0                      44  [(game, NN), (must, MD), (developed, VB), (usi...
# 1                      60  [(game, NN), (must, MD), (programmed, VB), (us...
# 2                      75  [(game, NN), (must, MD), (feature, VB), (accur...
# 3                      41  [(game, NN), (must, MD), (playable, VB), (usin...
# 4                      63  [(game, NN), (must, MD), (offer, VB), (compell...
# 5                      59  [(game, NN), (must, MD), (implement, VB), (ai,...
# 6                      60  [(game, NN), (must, MD), (challenge, VB), (use...
# 7                      32  [(user, RB), (shall, MD), (able, JJ), (registe...
# 8                      34      [(login, NN), (available, JJ), (website, NN)]
# 9                      53  [(request, NN), (cricket, NN), (tournament, NN...
# 10                     37  [(name, NN), (tournament, NN), (available, JJ)...
# 11                     53  [(starting, VBG), (ending, VBG), (date, NN), (...
# 12                     49  [(team, NN), (player, NN), (names, NNS), (,, ,...
# 13                     37  [(website, JJ), (shall, MD), (assign, VB), (us...
# 14                     92  [(player, NN), (firstname, NN), (lastname, NN)...
# 15                     56  [(player, NN), (specific, JJ), (player, NN), (...
# 16                     48  [(website, JJ), (shall, MD), (enable, VB), (st...
# 17                     41  [(website, NN), (also, RB), (store, NN), (date...
# 18                     52  [(every, DT), (match, NN), (detail, NN), (spec...
# 19                     56  [(every, DT), (match, NN), (specific, JJ), (sc...
# 20                     62  [(match, NN), (scorecard, NN), (contain, VBP),...
#
#                                  Boilerplate Sentence
# 0   The system shall developed using unity game en...
# 1   The system shall programmed using c library co...
# 2   The system shall feature accurate sound game e...
# 3   The system shall playable using keyboard game ...
# 4   The system shall offer compelling special game...
# 5   The system shall implement offer ai complete g...
# 6   The system shall challenge build user complete...
# 7              The system shall  able register system
# 8           The system shall  available login website
# 9   The system shall  available request cricket to...
# 10  The system shall  available name tournament sy...
# 11  The system shall starting ending available dat...
# 12  The system shall  contact team player number c...
# 13   The system shall assign website user specific id
# 14  The system shall  dob email player firstname l...
# 15          The system shall  specific player id team
# 16  The system shall enable website store role bat...
# 17  The system shall   website store date tourname...
# 18         The system shall  specific match detail id
# 19  The system shall  specific scorecard match acc...
# 20  The system shall contain total specific match ...

# %%
pip install pyspellchecker
# Out:
# Requirement already satisfied: pyspellchecker in c:\users\wb\anaconda3\lib\site-packages (0.7.1)Note: you may need to restart the kernel to use updated packages.

# %%
from spellchecker import SpellChecker

# %%
spell = SpellChecker(distance=1)
def Correct(x):
    return spell.correction(x)
data["Boilerplate Sentence"] = data["Boilerplate Sentence"].apply(Correct)

# %%
data.head()
# Out:
#    index                                   Raw Requirements  \
# 0      0        game must developed using unity game engine
# 1      1  game must programmed using c# language library...
# 2      2  game must feature accurate sound effect music ...
# 3      3        game must playable using keyboard key mouse
# 4      4  game must offer compelling story convey specia...
#
#                     Requirement with Standard Syntax   type Domain  \
# 0       game shall developed using unity game engine      0   Game
# 1  game shall written c# use unity engine-compati...      0   Game
# 2  game shall feature accurate sound effect music...      0   Game
# 3          game shall playable using mouse keyboard.      0   Game
# 4  game shall offer compelling story convey speci...      0   Game
#
#    sub_domain  raw_length  standard_length  clean_raw_length  \
# 0  Mobile app          54               51                43
# 1  Mobile app         100               74                70
# 2  Mobile app          92               93                74
# 3  Mobile app          59               52                43
# 4  Mobile app          89               90                62
#
#    clean_standard_length                                                POS  \
# 0                     44  [(game, NN), (must, MD), (developed, VB), (usi...
# 1                     60  [(game, NN), (must, MD), (programmed, VB), (us...
# 2                     75  [(game, NN), (must, MD), (feature, VB), (accur...
# 3                     41  [(game, NN), (must, MD), (playable, VB), (usin...
# 4                     63  [(game, NN), (must, MD), (offer, VB), (compell...
#
#                                 Boilerplate Sentence
# 0  The system shall developed using unity game en...
# 1  The system shall programmed using c library co...
# 2  The system shall feature accurate sound game e...
# 3  The system shall playable using keyboard game ...
# 4  The system shall offer compelling special game...

# %%
data.to_csv('file_name.csv', index=False,header=True)

# %%
data.columns
# Out:
# Index(['index', 'Raw Requirements', 'Requirement with Standard Syntax',
#        ' type', 'Domain', 'sub_domain', 'raw_length', 'standard_length',
#        'clean_raw_length', 'clean_standard_length', 'POS',
#        'Boilerplate Sentence'],
#       dtype='object')

# %%
import difflib
text_1='Raw Requirements'
text_2="Requirement with Standard Syntax"
text_3="Boilerplate Sentence"
sequence=difflib.SequenceMatcher(isjunk=None, a=text_1,b=text_2)
difference= sequence.ratio()*100
difference=round(difference, 1)
print(f'{difference} % match')
# Out:
# 45.8 % match

# %%
Raw = data['Raw Requirements']

# %%
Raw[0]
# Out:
# 'game must developed using unity game engine'

# %%
Standard = data['Requirement with Standard Syntax']

# %%
Standard[0]
# Out:
# 'game shall developed using unity game engine'

# %%
BP = data['Boilerplate Sentence']

# %%
BP[0]
# Out:
# 'The system shall developed using unity game engine'

# %%
data['Raw with Boiler'] = ''
data['Standard with Boiler'] = ''

# %%
import difflib

# %%
for s in range(data.shape[0]):
    sequence=difflib.SequenceMatcher(isjunk=None, a=Raw[s],b=BP[s])
    try:
        difference= sequence.ratio()*100
    except:
        print("Error in loading raw with boiler {}".format(s))
    difference=round(difference, 1)
    data['Raw with Boiler'].iloc[s]= difference

    sequence=difflib.SequenceMatcher(isjunk=None, a=Standard[s],b=BP[s])
    try:
        difference= sequence.ratio()*100
    except:
        print("error Loading standard with boiler {}".format(s))
    difference=round(difference, 1)
    data['Standard with Boiler'].iloc[s]= difference

# %%
data
# Out:
#     index                                   Raw Requirements  \
# 0       0        game must developed using unity game engine
# 1       1  game must programmed using c# language library...
# 2       2  game must feature accurate sound effect music ...
# 3       3        game must playable using keyboard key mouse
# 4       4  game must offer compelling story convey specia...
# 5       5  game must implement ai enemy npc offer complet...
# 6       6  game must challenge user think build strategy ...
# 7       7                   user shall able register system.
# 8       8                            login available website
# 9       9         request cricket tournament available user.
# 10     10                   name tournament available system
# 11     11          starting ending date tournament available
# 12     12        team player names, contact number city name
# 13     13             website shall assign user specific id.
# 14     14  player firstname lastname dob email contact ci...
# 15     15                 player specific player id team id.
# 16     16  website shall enable store role (batsmen/bowle...
# 17     17          website also store date tournament match.
# 18     18        every match detail specific match detail id
# 19     19  every match specific scorecard access match de...
# 20     20   match scorecard contain total run specific match
#
#                      Requirement with Standard Syntax   type Domain  \
# 0        game shall developed using unity game engine      0   Game
# 1   game shall written c# use unity engine-compati...      0   Game
# 2   game shall feature accurate sound effect music...      0   Game
# 3           game shall playable using mouse keyboard.      0   Game
# 4   game shall offer compelling story convey speci...      0   Game
# 5   game shall implement ai enemy npc offer comple...      0   Game
# 6   game shall challenge user think build strategy...      0   Game
# 7                    system shall allow user register      0   Game
# 8                  system shall provide login option.      0   Game
# 9   system shall provide request cricket tournamen...      0   Game
# 10              system shall provide name tournament.      0   Game
# 11  system shall provide starting ending date tour...      0   Game
# 12  team player shall names, contact number city name      0   Game
# 13              system shall assign user specific id.      0   Game
# 14  system shall allow player enter first name, la...      0   Game
# 15  system shall provide specific player id team i...      0   Game
# 16   system shall store role (batsmen/bowler) player.      0   Game
# 17          system shall store date tournament match.      0   Game
# 18  system shall provide specific id every match d...      0   Game
# 19  system shall able specific scorecard access ma...      0   Game
# 20  system shall match scorecard contain total run...      0   Game
#
#     sub_domain  raw_length  standard_length  clean_raw_length  \
# 0   Mobile app          54               51                43
# 1   Mobile app         100               74                70
# 2   Mobile app          92               93                74
# 3   Mobile app          59               52                43
# 4   Mobile app          89               90                62
# 5   Mobile app          81               82                58
# 6   Mobile app          83               84                59
# 7   Mobile app          54               43                32
# 8   Mobile app          40               40                23
# 9   Mobile app          59               68                42
# 10  Mobile app          52               48                32
# 11  Mobile app          58               64                41
# 12  Mobile app          72               73                43
# 13  Mobile app          48               47                38
# 14  Mobile app          84              113                56
# 15  Mobile app          64               76                34
# 16  Mobile app          75               64                56
# 17  Mobile app          61               56                41
# 18  Mobile app          55               61                43
# 19  Mobile app          84               96                50
# 20  Mobile app          69               93                48
#
#     clean_standard_length                                                POS  \
# 0                      44  [(game, NN), (must, MD), (developed, VB), (usi...
# 1                      60  [(game, NN), (must, MD), (programmed, VB), (us...
# 2                      75  [(game, NN), (must, MD), (feature, VB), (accur...
# 3                      41  [(game, NN), (must, MD), (playable, VB), (usin...
# 4                      63  [(game, NN), (must, MD), (offer, VB), (compell...
# 5                      59  [(game, NN), (must, MD), (implement, VB), (ai,...
# 6                      60  [(game, NN), (must, MD), (challenge, VB), (use...
# 7                      32  [(user, RB), (shall, MD), (able, JJ), (registe...
# 8                      34      [(login, NN), (available, JJ), (website, NN)]
# 9                      53  [(request, NN), (cricket, NN), (tournament, NN...
# 10                     37  [(name, NN), (tournament, NN), (available, JJ)...
# 11                     53  [(starting, VBG), (ending, VBG), (date, NN), (...
# 12                     49  [(team, NN), (player, NN), (names, NNS), (,, ,...
# 13                     37  [(website, JJ), (shall, MD), (assign, VB), (us...
# 14                     92  [(player, NN), (firstname, NN), (lastname, NN)...
# 15                     56  [(player, NN), (specific, JJ), (player, NN), (...
# 16                     48  [(website, JJ), (shall, MD), (enable, VB), (st...
# 17                     41  [(website, NN), (also, RB), (store, NN), (date...
# 18                     52  [(every, DT), (match, NN), (detail, NN), (spec...
# 19                     56  [(every, DT), (match, NN), (specific, JJ), (sc...
# 20                     62  [(match, NN), (scorecard, NN), (contain, VBP),...
#
#                                  Boilerplate Sentence Raw with Boiler  \
# 0   The system shall developed using unity game en...            81.7
# 1   The system shall programmed using c library co...            72.8
# 2   The system shall feature accurate sound game e...            69.1
# 3   The system shall playable using keyboard game ...            77.6
# 4   The system shall offer compelling special game...            72.1
# 5   The system shall implement offer ai complete g...            59.4
# 6   The system shall challenge build user complete...            59.2
# 7              The system shall  able register system            82.9
# 8           The system shall  available login website            59.4
# 9   The system shall  available request cricket to...            61.4
# 10  The system shall  available name tournament sy...            53.7
# 11  The system shall starting ending available dat...            62.6
# 12  The system shall  contact team player number c...            57.7
# 13   The system shall assign website user specific id            79.1
# 14  The system shall  dob email player firstname l...            70.8
# 15          The system shall  specific player id team            66.7
# 16  The system shall enable website store role bat...            83.3
# 17  The system shall   website store date tourname...            73.7
# 18         The system shall  specific match detail id            70.6
# 19  The system shall  specific scorecard match acc...            69.8
# 20  The system shall contain total specific match ...            35.5
#
#    Standard with Boiler
# 0                  87.2
# 1                  38.3
# 2                  72.9
# 3                  64.6
# 4                  75.9
# 5                  63.6
# 6                  63.5
# 7                  71.4
# 8                  64.0
# 9                  85.7
# 10                 73.6
# 11                 79.3
# 12                 54.4
# 13                 84.7
# 14                 69.9
# 15                 76.3
# 16                 80.4
# 17                 84.2
# 18                 74.5
# 19                 82.1
# 20                 52.9

# %%
data.sub_domain.unique()
# Out:
# array(['Mobile app'], dtype=object)

# %%
for s in data.sub_domain.unique():
    print(s)
# Out:
# Mobile app

# %%
sampling = pd.DataFrame(columns=data.sub_domain.unique())

# %%
sampling
# Out:
# Empty DataFrame
# Columns: [Mobile app]
# Index: []

# %%
data.groupby('sub_domain').size()
# Out:
# sub_domain
# Mobile app    21
# dtype: int64

# %%
from random import randint

# %%
sampling.columns
# Out:
# Index(['Mobile app'], dtype='object')

# %%
list=[]
final_samples=[]

# %%
import random
for sd in data.sub_domain.unique():
    while True:
        rand = random.randint(0,data.shape[0]-1)
        if data.iloc[rand].sub_domain == sd:
            if rand not in list: 
                list.append(rand)
        if len(list)==1:
            print(list)
            final_samples.extend(list)
            list=[]
            break
# Out:
# [8]

# %%
len(data)
# Out:
# 21

# %%
val_df = []
for samp in final_samples:
    val = data.iloc[[samp]]
    val_df.append(pd.DataFrame(val))
    #print(val)
    #print(samp)

# %%
val_1 = val_df[0].iloc[:,-3:-2]
val_2 = val_df[1].iloc[:,-3:-2]
val_3 = val_df[2].iloc[:,-3:-2]
val_4 = val_df[3].iloc[:,-3:-2]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1860\3765382986.py in <module>
#       1 val_1 = val_df[0].iloc[:,-3:-2]
# ----> 2 val_2 = val_df[1].iloc[:,-3:-2]
#       3 val_3 = val_df[2].iloc[:,-3:-2]
#       4 val_4 = val_df[3].iloc[:,-3:-2]
#
# IndexError: list index out of range

# %%
final_val = pd.concat([val_1, val_2,val_3,val_4])
final_val.head()
# Out:
#                                    Boilerplate Sentence
# 839   The system shall allow email send enter system...
# 705   The system shall conducted  paper course code ...
# 1022  The system shall allow  system client project ...
# 552                                                None

# %%
len(final_samples)
# Out:
# 4

# %%
NN = []
VB = []
JJ = []

# %%
for samp in final_samples:
    for s in range(len(data['POS'][samp])):
        if data['POS'][samp][s][1]=='NN':
            if data['POS'][samp][s][0] not in NN:
                NN.append(data['POS'][samp][s][0])
        if 'VB' in data['POS'][samp][s][1]:
            if data['POS'][samp][s][0] not in VB:
                VB.append(data['POS'][samp][s][0])
        if data['POS'][samp][s][1]=='JJ':
            if data['POS'][samp][s][0] not in JJ:
                JJ.append(data['POS'][samp][s][0])

# %%
print(len(NN))
print(NN)
# Out:
# 17
# ['system', 'change', 'password', 'link', 'email', 'paper', 'course', 'code', 'batch', 'day', 'time', 'client', 'project', 'manager', 'view', 'supervisor', 'update']

# %%
print(len(VB))
print(VB)
# Out:
# 4
# ['allow', 'email', 'send', 'conducted']

# %%
print(len(JJ))
print(JJ)
# Out:
# 1
# ['enter']

# %%
new_gen_req = []

# %%
for n in range(len(NN)):
    for j in range(len(JJ)):
        for v in range(len(VB)):
            new_gen_req.append('The system shall '+VB[v]+' '+JJ[j]+' '+NN[n])

# %%
len(new_gen_req)
# Out:
# 68

# %%
new_gen_req
# Out:
# ['The system shall allow enter system',
#  'The system shall email enter system',
#  'The system shall send enter system',
#  'The system shall conducted enter system',
#  'The system shall allow enter change',
#  'The system shall email enter change',
#  'The system shall send enter change',
#  'The system shall conducted enter change',
#  'The system shall allow enter password',
#  'The system shall email enter password',
#  'The system shall send enter password',
#  'The system shall conducted enter password',
#  'The system shall allow enter link',
#  'The system shall email enter link',
#  'The system shall send enter link',
#  'The system shall conducted enter link',
#  'The system shall allow enter email',
#  'The system shall email enter email',
#  'The system shall send enter email',
#  'The system shall conducted enter email',
#  'The system shall allow enter paper',
#  'The system shall email enter paper',
#  'The system shall send enter paper',
#  'The system shall conducted enter paper',
#  'The system shall allow enter course',
#  'The system shall email enter course',
#  'The system shall send enter course',
#  'The system shall conducted enter course',
#  'The system shall allow enter code',
#  'The system shall email enter code',
#  'The system shall send enter code',
#  'The system shall conducted enter code',
#  'The system shall allow enter batch',
#  'The system shall email enter batch',
#  'The system shall send enter batch',
#  'The system shall conducted enter batch',
#  'The system shall allow enter day',
#  'The system shall email enter day',
#  'The system shall send enter day',
#  'The system shall conducted enter day',
#  'The system shall allow enter time',
#  'The system shall email enter time',
#  'The system shall send enter time',
#  'The system shall conducted enter time',
#  'The system shall allow enter client',
#  'The system shall email enter client',
#  'The system shall send enter client',
#  'The system shall conducted enter client',
#  'The system shall allow enter project',
#  'The system shall email enter project',
#  'The system shall send enter project',
#  'The system shall conducted enter project',
#  'The system shall allow enter manager',
#  'The system shall email enter manager',
#  'The system shall send enter manager',
#  'The system shall conducted enter manager',
#  'The system shall allow enter view',
#  'The system shall email enter view',
#  'The system shall send enter view',
#  'The system shall conducted enter view',
#  'The system shall allow enter supervisor',
#  'The system shall email enter supervisor',
#  'The system shall send enter supervisor',
#  'The system shall conducted enter supervisor',
#  'The system shall allow enter update',
#  'The system shall email enter update',
#  'The system shall send enter update',
#  'The system shall conducted enter update']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
X = new_gen_req
tfidf = TfidfVectorizer()
tfidf.fit(X)
transformed = tfidf.transform(X)
X_train = transformed
X_train = X_train.todense()

# Get the name of Features (Feature  Set) and create a DataFrame of Input Features
input_training_features = pd.DataFrame(X_train, columns = tfidf.get_feature_names())
input_training_features.head()
# Out:
#       allow  batch    change  client  code  conducted  course  day     email  \
# 0  0.663092    0.0  0.000000     0.0   0.0   0.000000     0.0  0.0  0.000000
# 1  0.000000    0.0  0.000000     0.0   0.0   0.000000     0.0  0.0  0.637567
# 2  0.000000    0.0  0.000000     0.0   0.0   0.000000     0.0  0.0  0.000000
# 3  0.000000    0.0  0.000000     0.0   0.0   0.663092     0.0  0.0  0.000000
# 4  0.492667    0.0  0.761927     0.0   0.0   0.000000     0.0  0.0  0.000000
#
#       enter  ...  password  project      send     shall  supervisor    system  \
# 0  0.282921  ...       0.0      0.0  0.000000  0.282921         0.0  0.565842
# 1  0.291182  ...       0.0      0.0  0.000000  0.291182         0.0  0.582364
# 2  0.282921  ...       0.0      0.0  0.663092  0.282921         0.0  0.565842
# 3  0.282921  ...       0.0      0.0  0.000000  0.282921         0.0  0.565842
# 4  0.210206  ...       0.0      0.0  0.000000  0.210206         0.0  0.210206
#
#         the  time  update  view
# 0  0.282921   0.0     0.0   0.0
# 1  0.291182   0.0     0.0   0.0
# 2  0.282921   0.0     0.0   0.0
# 3  0.282921   0.0     0.0   0.0
# 4  0.210206   0.0     0.0   0.0
#
# [5 rows x 23 columns]

# %%
val_2
# Out:
#                                   Boilerplate Sentence
# 705  The system shall conducted  paper course code ...

# %%
values = [val_1,val_2,val_3,val_4]
output_training_features = []
for i in values:
    try:
        y = tfidf.transform(i["Boilerplate Sentence"])
        y_train = y.todense()
        # Get the name of Features (Feature  Set) and create a DataFrame of Input Features
        output_training_features.append(pd.DataFrame(y_train, columns = tfidf.get_feature_names()))
    except:
        print("None")
# Out:
# None

# %%
len(output_training_features)
# Out:
# 3

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarities_values = []
for i in range (len(output_training_features)):
    for j in range(len(input_training_features)):
        score = cosine_similarity(output_training_features[i],input_training_features.iloc[j:j+1,:])
        #print("Score for value i ", i," and j ", j, " Score-> ",score)
        similarities_values.append(score)

# %%
count = 0
values = []
for i in similarities_values:
    if i < 0.5:
        count = count+1
        values.append(i)
        print(i)
        
print("TOtal Count is ",count)
# Out:
# [[0.40390857]]
# [[0.40390857]]
# [[0.22631386]]
# [[0.43570036]]
# [[0.43570036]]
# [[0.43570036]]
# [[0.44104637]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.2520558]]
# [[0.35597241]]
# [[0.2520558]]
# [[0.12010558]]
# [[0.12110501]]
# [[0.12464114]]
# [[0.12110501]]
# [[0.28741527]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.08493412]]
# [[0.06668508]]
# [[0.08493412]]
# [[0.24045112]]
# [[0.36302614]]
# [[0.36876417]]
# [[0.36302614]]
# [[0.48659218]]
# [[0.36302614]]
# [[0.36876417]]
# [[0.36302614]]
# [[0.48659218]]
# [[0.36302614]]
# [[0.36876417]]
# [[0.36302614]]
# [[0.48659218]]
# [[0.36302614]]
# [[0.36876417]]
# [[0.36302614]]
# [[0.48659218]]
# [[0.36302614]]
# [[0.36876417]]
# [[0.36302614]]
# [[0.48659218]]
# [[0.36302614]]
# [[0.36876417]]
# [[0.36302614]]
# [[0.48659218]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.06748441]]
# [[0.06855108]]
# [[0.06748441]]
# [[0.19105045]]
# [[0.40630857]]
# [[0.21830798]]
# [[0.21211448]]
# [[0.21211448]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.31382361]]
# [[0.1038208]]
# [[0.1322324]]
# [[0.1322324]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.4572732]]
# [[0.45015796]]
# [[0.45015796]]
# [[0.4572732]]
# [[0.45015796]]
# [[0.45015796]]
# [[0.4572732]]
# [[0.45015796]]
# [[0.45015796]]
# [[0.4572732]]
# [[0.45015796]]
# [[0.45015796]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# [[0.24934857]]
# [[0.10672594]]
# [[0.10506526]]
# [[0.10506526]]
# TOtal Count is  187

# %%
print("The Average is ",np.mean(values))
# Out:
# The Average is  0.22516029940605392
